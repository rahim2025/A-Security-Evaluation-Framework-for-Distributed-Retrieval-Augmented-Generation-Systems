# %% [markdown]
# Use the following command to start the service with default settings for local test
#
# > docker compose up --build - d
#
# This might take long as it needs to embed documents for 3 data sources.

# %% [markdown]
# Once it's done, run the following cells to test.

# %%
# Default settings
llm_service_url = "http://localhost:9000"

# Test cases
example_data = [
        {"question": "who got the first nobel prize in physics", "answers": ["wilhelm conrad r\u00f6ntgen"]},
        {"question": "when is the next deadpool movie being released", "answers": ["may 18, 2018"]},
        {"question": "which mode is used for short wave broadcast service", "answers": ["mfsk", "olivia"]},
        {"question": "the south west wind blows across nigeria between", "answers": ["till september"]},
        {"question": "who wrote the first declaration of human rights", "answers": ["cyrus"]},
        {"question": "who is the owner of reading football club", "answers": ["dai xiuli", "dai yongge", "xiu li dai", "yongge dai"]},
        {"question": "when is the next scandal episode coming out", "answers": ["february 1, 2018"]},
        {"question": "when is the last time the philadelphia won the superbowl", "answers": ["2017", "super bowl lii,"]},
        {"question": "who was the first lady nominated member of the rajya sabha", "answers": ["mary kom"]},
        {"question": "what is the most current adobe flash player version", "answers": ["28.0.0.137"]},
        {"question": "swan lake the sleeping beauty and the nutcracker are three famous ballets by", "answers": ["pyotr ilyich tchaikovsky"]}
    ]

# %%
import requests
from drag_llm_service.test_service import *

test_health_check_data_sources()
# Out:
# Testing health check for data sources...
# Status: 200
# Overall status: healthy
# Data sources status:
#   - sources_0: healthy (healthy)
#   - sources_100: healthy (healthy)
#   - sources_20: healthy (healthy)
# True

# %%
# Test query endpoint that returns just the response.
test_query(query="Who won the first Nobel Prize in Physics")
# Out:
# Testing query: 'Who won the first Nobel Prize in Physics'...
# Status: 200
# Response: system
# Albert Zahm
# True

# %%
test_query_analyze_sse(query="Who won the first Nobel Prize in Physics", ground_truth=[" Wilhelm Conrad Röntgen"], update_scores=True)
# Out:
# Testing query_analyze with SSE: 'Who won the first Nobel Prize in Physics'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# Albert Zahm...
# [mc_shap_progress] Processing: 15/15 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] completed
#   ✓ Transaction hash: 1656f87a2c02744e5260fe3fc80a6f7b171adc05be050a111f69bf4356a99ef8
# [final_result] Received final result
#   Response: system
# Albert Zahm...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9994.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9966.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: completed
#       ✓ Score update transaction completed
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nAlbert Zahm', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 0.03287153672006151], ['sources_100', 0.0], ['sources_100', 0.1671284632799385]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9994.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9966.0}}}
# SSE test completed successfully! (Score updates included in final result)
# True

# %%
# test all example data
for i in range(len(example_data)):
    test_query_analyze_sse(query=example_data[i]["question"], ground_truth=example_data[i]["answers"], update_scores=True)
# Out:
# Testing query_analyze with SSE: 'who got the first nobel prize in physics'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# none...
# [mc_shap_progress] Processing: 15/15 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] error
#   ✗ Error: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0xc91df162b9f7bc1ffc50017710c9bdcaa19d54278d75d9fdb47ea61c30ce15dc', 'data': ''}}
# [final_result] Received final result
#   Response: system
# none...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9994.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9966.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: error
#       ✗ Score update failed: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0xc91df162b9f7bc1ffc50017710c9bdcaa19d54278d75d9fdb47ea61c30ce15dc', 'data': ''}}
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nnone', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_100', 0.026528859605010353], ['sources_20', 0.053057719210020705], ['sources_100', 0.12041342118496892]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9994.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9966.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'when is the next deadpool movie being released'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# 2025...
# [mc_shap_progress] Processing: 13/13 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] completed
#   ✓ Transaction hash: 8f461447d821045f5a60233946d0d241bf7e21c24264fb3bbcaba788bbcdda83
# [final_result] Received final result
#   Response: system
# 2025...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9980.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: completed
#       ✓ Score update transaction completed
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\n2025', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 0.08475189916405686], ['sources_20', 0.06037215125391472], ['sources_100', 0.08390075966562274]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9980.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'which mode is used for short wave broadcast service'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# FM...
# [mc_shap_progress] Processing: 18/18 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] error
#   ✗ Error: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0x0dfe1e64eeef75a03ec3998eca4cc78f340cde7aece0fc1b9434e25bab0ad40a', 'data': ''}}
# [final_result] Received final result
#   Response: system
# FM...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9980.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: error
#       ✗ Score update failed: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0x0dfe1e64eeef75a03ec3998eca4cc78f340cde7aece0fc1b9434e25bab0ad40a', 'data': ''}}
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nFM', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_0', 0.05194937427772391], ['sources_100', 0.05954313633555322], ['sources_20', 0.05885661723165435]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9980.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'the south west wind blows across nigeria between'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# clouds...
# [mc_shap_progress] Processing: 20/20 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] completed
#   ✓ Transaction hash: 303e7e04c7553a9e8d565219abd712435398c241927b91c6644bada6c08808f2
# [final_result] Received final result
#   Response: system
# clouds...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9967.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: completed
#       ✓ Score update transaction completed
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nclouds', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 0.07334122848514275], ['sources_100', 0.0], ['sources_20', 0.05665482393895255]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9967.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'who wrote the first declaration of human rights'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# UN General Assembly...
# [mc_shap_progress] Processing: 10/10 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] error
#   ✗ Error: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_20", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_20", 1)\'', 'txHash': '0x48a5d5c9c6ca1fbf21842f360cf897250485121bfc8c3de6be4b68bff77247df', 'data': ''}}
# [final_result] Received final result
#   Response: system
# UN General Assembly...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9967.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: error
#       ✗ Score update failed: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_20", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_20", 1)\'', 'txHash': '0x48a5d5c9c6ca1fbf21842f360cf897250485121bfc8c3de6be4b68bff77247df', 'data': ''}}
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nUN General Assembly', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 0.16666666666666666], ['sources_100', 0.0], ['sources_20', 0.125]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9967.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9958.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'who is the owner of reading football club'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# Not applicable...
# [mc_shap_progress] Processing: 34/34 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] completed
#   ✓ Transaction hash: 98b1c256bcf333823872d11fb3c15de717f04581a6a3c989674a56ff0622a785
# [final_result] Received final result
#   Response: system
# Not applicable...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9962.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: completed
#       ✓ Score update transaction completed
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nNot applicable', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 2.303989721716954e-17], ['sources_100', 0.022504225768125257], ['sources_20', 0.04566272261641644]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9962.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'when is the next scandal episode coming out'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# unknown...
# [mc_shap_progress] Processing: 10/10 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] error
#   ✗ Error: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0xc9d635057ea13ef0a39802b480d72487aef728c84de6701127ed06f05a5912b7', 'data': ''}}
# [final_result] Received final result
#   Response: system
# unknown...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9962.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: error
#       ✗ Score update failed: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0xc9d635057ea13ef0a39802b480d72487aef728c84de6701127ed06f05a5912b7', 'data': ''}}
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nunknown', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_100', 0.0], ['sources_100', 0.0], ['sources_20', 0.25]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9962.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'when is the last time the philadelphia won the superbowl'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# 2017...
# [mc_shap_progress] Processing: 27/27 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] completed
#   ✓ Transaction hash: 3017f0ff78370d81a10c3743b539e359abe0731103564f4d418ec5ddab2ea7f6
# [final_result] Received final result
#   Response: system
# 2017...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9953.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: completed
#       ✓ Score update transaction completed
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\n2017', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 0.0728769498680167], ['sources_100', 0.0], ['sources_20', 0.015684575197974945]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9953.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'who was the first lady nominated member of the rajya sabha'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# unknown...
# [mc_shap_progress] Processing: 18/18 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] error
#   ✗ Error: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0x86d22d0bf26ce8d973da5e3280600a34869ec68d23c0df9e58e80812a1dbd6cf', 'data': ''}}
# [final_result] Received final result
#   Response: system
# unknown...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9953.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: error
#       ✗ Score update failed: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0x86d22d0bf26ce8d973da5e3280600a34869ec68d23c0df9e58e80812a1dbd6cf', 'data': ''}}
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nunknown', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_100', 0.07260741351590014], ['sources_20', 0.04175333024326326], ['sources_100', 0.053524535150522905]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9953.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9956.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'what is the most current adobe flash player version'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# 2020...
# [mc_shap_progress] Processing: 15/15 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] completed
#   ✓ Transaction hash: 7b7e701874670fbcb2b3304a595a460ef9499ecd6ac540d9b6124eaba171a027
# [final_result] Received final result
#   Response: system
# 2020...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9940.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9947.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: completed
#       ✓ Score update transaction completed
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\n2020', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_20', 0.0], ['sources_100', 0.08833217940701338], ['sources_20', 0.1293342564743893]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9940.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9947.0}}}
# SSE test completed successfully! (Score updates included in final result)
#
# Testing query_analyze with SSE: 'swan lake the sleeping beauty and the nutcracker are three famous ballets by'...
#   (with score updates enabled)
# Status: 200
# Receiving SSE events...
# ------------------------------------------------------------
# [sampling_sources] Sources: ['sources_0', 'sources_20', 'sources_100']
# [querying_sources] sources_0: querying
# [querying_sources] sources_0: success (3 results)
# [querying_sources] sources_20: querying
# [querying_sources] sources_20: success (3 results)
# [querying_sources] sources_100: querying
# [querying_sources] sources_100: success (3 results)
# [reranking] starting - Selected: 0
# [reranking] completed - Selected: 3
# [mc_shap] starting
# [mc_shap_baseline] Baseline calculated: system
# Tchaikovsky...
# [mc_shap_progress] Processing: 9/9 (100.0%)
# [computing_importance] starting - Sources: 0
# [computing_importance] completed - Sources: 3
# [updating_scores] starting
# [updating_scores] error
#   ✗ Error: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0x83c4aa3b876607e80aa146ec6e4caf72639f615ddfba6c624772d042b6853c22', 'data': ''}}
# [final_result] Received final result
#   Response: system
# Tchaikovsky...
#   Correctness: False
#   Sampled sources: ['sources_0', 'sources_20', 'sources_100']
#   Updated scores: {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9940.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9947.0}}
# ------------------------------------------------------------
#   Score update events received: 2
#     Event 1: starting
#     Event 2: error
#       ✗ Score update failed: {'code': -32603, 'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'data': {'message': 'Error: VM Exception while processing transaction: reverted with custom error \'UpdateTooFrequent("sources_100", 1)\'', 'txHash': '0x83c4aa3b876607e80aa146ec6e4caf72639f615ddfba6c624772d042b6853c22', 'data': ''}}
#   Updated scores for sources: ['sources_0', 'sources_20', 'sources_100']
# {'response': 'system\nTchaikovsky', 'correctness': False, 'sampled_sources': ['sources_0', 'sources_20', 'sources_100'], 'importance_score': [['sources_100', 0.0], ['sources_100', 0.0], ['sources_20', 0.3333333333333333]], 'updated_scores': {'sources_0': {'reliability': 10000.0, 'usefulness': 10000.0}, 'sources_20': {'reliability': 10000.0, 'usefulness': 9940.0}, 'sources_100': {'reliability': 10000.0, 'usefulness': 9947.0}}}
# SSE test completed successfully! (Score updates included in final result)

# %%
# Check the score update events for all data sources
test_score_events()
# Out:
# Testing score_events endpoint...
# Status: 200
# Retrieved 14 score update event(s)
# Recent events:
#   Event 1:
#     Source Name: sources_100
#     Source ID: 0x6818894b9ccf63c5a27fb8e6891708135d1d2c057585a6afa9d18e2c8cfcce75
#     Source Address: 0x3C44CdDdB6a900fa2b585dd299e03d12FA4293BC
#     Reliability Score: 10000
#     Usefulness Score: 9956
#     Block Number: 12
#     Transaction Hash: 0x98b1c256bcf333823872d11fb3c15de717f04581a6a3c989674a56ff0622a785
#     Info: {"correctness": false, "importance_score": [["sources_20", 2.303989721716954e-17], ["sources_100", 0...
#
#   Event 2:
#     Source Name: sources_20
#     Source ID: 0xaeeef63b4c81a93b275638a1a91a7b90adf4d6b05cafe0a71277b7d289d9298e
#     Source Address: 0x70997970C51812dc3A010C7d01b50e0d17dc79C8
#     Reliability Score: 10000
#     Usefulness Score: 9953
#     Block Number: 14
#     Transaction Hash: 0x3017f0ff78370d81a10c3743b539e359abe0731103564f4d418ec5ddab2ea7f6
#     Info: {"correctness": false, "importance_score": [["sources_20", 0.0728769498680167], ["sources_100", 0.0]...
#
#   Event 3:
#     Source Name: sources_100
#     Source ID: 0x6818894b9ccf63c5a27fb8e6891708135d1d2c057585a6afa9d18e2c8cfcce75
#     Source Address: 0x3C44CdDdB6a900fa2b585dd299e03d12FA4293BC
#     Reliability Score: 10000
#     Usefulness Score: 9956
#     Block Number: 14
#     Transaction Hash: 0x3017f0ff78370d81a10c3743b539e359abe0731103564f4d418ec5ddab2ea7f6
#     Info: {"correctness": false, "importance_score": [["sources_20", 0.0728769498680167], ["sources_100", 0.0]...
#
#   Event 4:
#     Source Name: sources_20
#     Source ID: 0xaeeef63b4c81a93b275638a1a91a7b90adf4d6b05cafe0a71277b7d289d9298e
#     Source Address: 0x70997970C51812dc3A010C7d01b50e0d17dc79C8
#     Reliability Score: 10000
#     Usefulness Score: 9940
#     Block Number: 16
#     Transaction Hash: 0x7b7e701874670fbcb2b3304a595a460ef9499ecd6ac540d9b6124eaba171a027
#     Info: {"correctness": false, "importance_score": [["sources_20", 0.0], ["sources_100", 0.08833217940701338...
#
#   Event 5:
#     Source Name: sources_100
#     Source ID: 0x6818894b9ccf63c5a27fb8e6891708135d1d2c057585a6afa9d18e2c8cfcce75
#     Source Address: 0x3C44CdDdB6a900fa2b585dd299e03d12FA4293BC
#     Reliability Score: 10000
#     Usefulness Score: 9947
#     Block Number: 16
#     Transaction Hash: 0x7b7e701874670fbcb2b3304a595a460ef9499ecd6ac540d9b6124eaba171a027
#     Info: {"correctness": false, "importance_score": [["sources_20", 0.0], ["sources_100", 0.08833217940701338...
# True
